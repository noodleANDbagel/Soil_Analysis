# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
import os

from sklearn.preprocessing import MinMaxScaler
#from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_confusion_matrix

# %%
pd.set_option('display.max_columns', None)

# %%
df_all= pd.read_csv('sanj_climate_soil_data_v3.csv')
df_all
# Out:
#               system:index                    B1                   B10  \
# 0     0000000000000000a7ab           0.156138506           291.4980281
# 1     00000000000000005cdf           0.147214935           291.6362041
# 2                 5.00E+17           0.146008425           291.2727592
# 3     000000000000000053a6           0.141016194           293.3909297
# 4                     5899            0.14787132           292.9200832
# ...                    ...                   ...                   ...
# 3773  000100000000000034b7           0.141586306           290.1301264
# 3774        3553459236846]  [-121.08301862332684   38.235531096975635]
# 3775  000100000000000034b8           0.151467255            289.654867
# 3776              77623969   38.066433794858106]   [-121.2959094555727
# 3777                419136    38.12679180342917]  [-121.25672735062051
#
#                        B11                    B2                    B3  \
# 0               290.941162           0.138696171           0.119764067
# 1              291.2270035           0.127864037           0.112383781
# 2              290.9031351           0.126529905           0.112544899
# 3              292.6746974           0.119396924           0.090475826
# 4              292.3048137           0.129631362           0.110078913
# ...                    ...                   ...                   ...
# 3773           289.8274426            0.12073968           0.100286631
# 3774  [-121.08335304158591    38.23552764112185]  [-121.08570741069968
# 3775           289.2609276           0.130318064           0.108825397
# 3776   38.066770794991484]  [-121.29568204972938    38.06746593768315]
# 3777    38.12627614612992]  [-121.25670062919185   38.125693831171525]
#
#                         B4                    B5                    B6  \
# 0              0.132345934           0.197404472           0.268907663
# 1              0.122462284           0.167657735           0.212057256
# 2              0.124327202           0.169578314           0.208004332
# 3              0.088609293            0.11902655           0.157171755
# 4              0.117618789           0.164422408           0.204815363
# ...                    ...                   ...                   ...
# 3773           0.100378611           0.180000974           0.174101788
# 3774    38.23551361055645]  [-121.08670626770119     38.2355066052644]
# 3775           0.106633392           0.185006325           0.168603393
# 3776  [-121.29555721639191   38.067764291457706]  [-121.29540113088527
# 3777   [-121.2566604597125    38.12564820663215]   [-121.2565355849393
#
#                         B7                    B8                    B9  \
# 0              0.212048671           0.122957659            0.00114323
# 1              0.174212108           0.114253015            0.00140626
# 2              0.170726854           0.114836886           0.001384199
# 3              0.123246598           0.089042376           0.001394305
# 4              0.167510555           0.111685891           0.001328958
# ...                    ...                   ...                   ...
# 3773           0.123306379           0.099202093           0.001365258
# 3774  [-121.08678654668935    38.23550662090511]  [-121.08871287649168
# 3775           0.124874877           0.107007829           0.004824992
# 3776    38.06817153980879]  [-121.29522278460755     38.0684980140537]
# 3777    38.12563768912591]  [-121.25442649115386    38.12555353945988]
#
#                     CLASS1 evaporation_from_bare_soil  \
# 0                        F                  -0.001711
# 1                        G                  -0.001935
# 2                        G                  -0.001935
# 3                        G                  -0.001796
# 4                        G                  -0.001796
# ...                    ...                        ...
# 3773                    UV                  -0.001516
# 3774    38.23549257144631]       [-121.08335304158591
# 3775                    UV                  -0.001661
# 3776  [-121.29518708040092        38.066770794991484]
# 3777  [-121.25240198060541         38.12627614612992]
#
#      evaporation_from_open_water_surfaces_excluding_oceans  \
# 0                                             -0.000309
# 1                                             -0.000303
# 2                                             -0.000303
# 3                                             -0.000381
# 4                                             -0.000381
# ...                                                 ...
# 3773                                          -0.000498
# 3774                                 38.23552764112185]
# 3775                                          -0.000541
# 3776                               [-121.29568204972938
# 3777                               [-121.25670062919185
#
#      evaporation_from_the_top_of_canopy  \
# 0                             -0.000264
# 1                             -0.000281
# 2                             -0.000281
# 3                             -0.000276
# 4                             -0.000276
# ...                                 ...
# 3773                           -0.00033
# 3774               [-121.08570741069968
# 3775                          -0.000276
# 3776                 38.06746593768315]
# 3777                38.125693831171525]
#
#      evaporation_from_vegetation_transpiration potential_evaporation  \
# 0                                            0             -0.005021
# 1                                            0              -0.00693
# 2                                            0              -0.00693
# 3                                     -0.00003             -0.006513
# 4                                     -0.00003             -0.006513
# ...                                        ...                   ...
# 3773                                  -0.00001             -0.005141
# 3774                        38.23551361055645]   [-121.0889046507768
# 3775                                         0              -0.00464
# 3776                      [-121.29555721639191   38.068838496423474]
# 3777                       [-121.2566604597125    38.12539568004988]
#
#           snow_evaporation     total_evaporation  total_precipitation  \
# 0                        0             -0.002283              0.00169
# 1                        0             -0.002518             0.001521
# 2                        0             -0.002518             0.001521
# 3                        0             -0.002482             0.001606
# 4                        0             -0.002482             0.001606
# ...                    ...                   ...                  ...
# 3773                     0             -0.002354             0.002512
# 3774   38.242094491600135]    38.24690289390949]  [-121.0889626289887
# 3775                     0             -0.002478             0.002058
# 3776  [-121.29303782428859  [-121.28370041232371   38.07724225643089]
# 3777  [-121.24796073779343  [-121.24820596415267   38.12657427178944]
#
#                     runoff volumetric_soil_water_layer_1  \
# 0                 0.000232                      0.340073
# 1                 0.000191                       0.30275
# 2                 0.000191                       0.30275
# 3                 0.000412                      0.258408
# 4                 0.000412                      0.258408
# ...                    ...                           ...
# 3773               0.00215                      0.432325
# 3774    38.23562216551106]            38.24838770201417]
# 3775              0.000442                      0.443161
# 3776  [-121.29471000481306          [-121.28327235560718
# 3777  [-121.25006549344954          [-121.24852708066182
#
#      volumetric_soil_water_layer_2 volumetric_soil_water_layer_3  \
# 0                          0.34613                       0.36882
# 1                         0.310059                      0.336517
# 2                         0.310059                      0.336517
# 3                          0.26799                      0.296051
# 4                          0.26799                      0.296051
# ...                            ...                           ...
# 3773                      0.440839                      0.436185
# 3774          [-121.08895370926558            38.24895499800474]
# 3775                      0.453354                      0.470551
# 3776            38.07750547723604]          [-121.28288891045293
# 3777            38.12717407330584]           [-121.2486429688364
#
#      volumetric_soil_water_layer_4  Unnamed: 26 surface_sensible_heat_flux  \
# 0                         0.344696          NaN                   -1900802
# 1                         0.277695          NaN                    -922280
# 2                         0.277695          NaN                    -922280
# 3                         0.264114          NaN                   -1048284
# 4                         0.264114          NaN                   -1048284
# ...                            ...          ...                        ...
# 3773                      0.429863          NaN               -1430555.667
# 3774          [-121.08894924940383          NaN       [-121.08898930070569
# 3775                      0.398979          NaN                   -1480625
# 3776           38.077758236466245]          NaN         38.07547312075403]
# 3777            38.12751791095224]          NaN         38.12603757119136]
#
#           skin_temperature u_component_of_wind_10m
# 0              285.8258514             0.928650856
# 1              285.8766327             1.283631325
# 2              285.8766327             1.283631325
# 3              285.6207733             1.314393044
# 4              285.6207733             1.314393044
# ...                    ...                     ...
# 3773           285.6197968              0.80926609
# 3774    38.23577276910855]      38.24745264190911]
# 3775           285.7994843             1.022156715
# 3776  [-121.29432650970925    [-121.28345517259677
# 3777  [-121.24950361181423    [-121.24838438172814
#
# [3778 rows x 30 columns]

# %%
column_list = df_all.columns

# %%
# select non-numeric value from 'B1' by using to_numeric, then delete these rows by using dropna

for col in column_list:
    df_all[col] = pd.to_numeric(df_all[col], errors='coerce')

# select all the rows without NaN values
df_clean = df_all[(df_all.B1.notnull())&(df_all.evaporation_from_bare_soil.notnull())]
df_clean
# Out:
#       system:index        B1         B10         B11        B2        B3  \
# 0              NaN  0.156139  291.498028  290.941162  0.138696  0.119764
# 1              NaN  0.147215  291.636204  291.227004  0.127864  0.112384
# 2     5.000000e+17  0.146008  291.272759  290.903135  0.126530  0.112545
# 3              NaN  0.141016  293.390930  292.674697  0.119397  0.090476
# 4     5.899000e+03  0.147871  292.920083  292.304814  0.129631  0.110079
# ...            ...       ...         ...         ...       ...       ...
# 3770           NaN  0.145618  291.055979  290.808012  0.127851  0.110812
# 3771           NaN  0.158675  291.433356  291.092085  0.142223  0.129631
# 3772           NaN  0.144910  290.155193  289.948144  0.125949  0.111344
# 3773           NaN  0.141586  290.130126  289.827443  0.120740  0.100287
# 3775           NaN  0.151467  289.654867  289.260928  0.130318  0.108825
#
#             B4        B5        B6        B7        B8        B9  CLASS1  \
# 0     0.132346  0.197404  0.268908  0.212049  0.122958  0.001143     NaN
# 1     0.122462  0.167658  0.212057  0.174212  0.114253  0.001406     NaN
# 2     0.124327  0.169578  0.208004  0.170727  0.114837  0.001384     NaN
# 3     0.088609  0.119027  0.157172  0.123247  0.089042  0.001394     NaN
# 4     0.117619  0.164422  0.204815  0.167511  0.111686  0.001329     NaN
# ...        ...       ...       ...       ...       ...       ...     ...
# 3770  0.121387  0.205664  0.234846  0.160223  0.111828  0.001175     NaN
# 3771  0.139927  0.197233  0.216785  0.174099  0.132532  0.001187     NaN
# 3772  0.123562  0.189587  0.214093  0.161634  0.114771  0.001104     NaN
# 3773  0.100379  0.180001  0.174102  0.123306  0.099202  0.001365     NaN
# 3775  0.106633  0.185006  0.168603  0.124875  0.107008  0.004825     NaN
#
#       evaporation_from_bare_soil  \
# 0                      -0.001711
# 1                      -0.001935
# 2                      -0.001935
# 3                      -0.001796
# 4                      -0.001796
# ...                          ...
# 3770                   -0.001560
# 3771                   -0.001560
# 3772                   -0.001591
# 3773                   -0.001516
# 3775                   -0.001661
#
#       evaporation_from_open_water_surfaces_excluding_oceans  \
# 0                                             -0.000309
# 1                                             -0.000303
# 2                                             -0.000303
# 3                                             -0.000381
# 4                                             -0.000381
# ...                                                 ...
# 3770                                          -0.000569
# 3771                                          -0.000569
# 3772                                          -0.000447
# 3773                                          -0.000498
# 3775                                          -0.000541
#
#       evaporation_from_the_top_of_canopy  \
# 0                              -0.000264
# 1                              -0.000281
# 2                              -0.000281
# 3                              -0.000276
# 4                              -0.000276
# ...                                  ...
# 3770                           -0.000275
# 3771                           -0.000275
# 3772                           -0.000314
# 3773                           -0.000330
# 3775                           -0.000276
#
#       evaporation_from_vegetation_transpiration  potential_evaporation  \
# 0                                      0.000000              -0.005021
# 1                                      0.000000              -0.006930
# 2                                      0.000000              -0.006930
# 3                                     -0.000030              -0.006513
# 4                                     -0.000030              -0.006513
# ...                                         ...                    ...
# 3770                                   0.000000              -0.004666
# 3771                                   0.000000              -0.004666
# 3772                                  -0.000004              -0.004743
# 3773                                  -0.000010              -0.005141
# 3775                                   0.000000              -0.004640
#
#       snow_evaporation  total_evaporation  total_precipitation    runoff  \
# 0                  0.0          -0.002283             0.001690  0.000232
# 1                  0.0          -0.002518             0.001521  0.000191
# 2                  0.0          -0.002518             0.001521  0.000191
# 3                  0.0          -0.002482             0.001606  0.000412
# 4                  0.0          -0.002482             0.001606  0.000412
# ...                ...                ...                  ...       ...
# 3770               0.0          -0.002404             0.002084  0.000337
# 3771               0.0          -0.002404             0.002084  0.000337
# 3772               0.0          -0.002356             0.002334  0.000787
# 3773               0.0          -0.002354             0.002512  0.002150
# 3775               0.0          -0.002478             0.002058  0.000442
#
#       volumetric_soil_water_layer_1  volumetric_soil_water_layer_2  \
# 0                          0.340073                       0.346130
# 1                          0.302750                       0.310059
# 2                          0.302750                       0.310059
# 3                          0.258408                       0.267990
# 4                          0.258408                       0.267990
# ...                             ...                            ...
# 3770                       0.550140                       0.559784
# 3771                       0.550140                       0.559784
# 3772                       0.568878                       0.576279
# 3773                       0.432325                       0.440839
# 3775                       0.443161                       0.453354
#
#       volumetric_soil_water_layer_3  volumetric_soil_water_layer_4  \
# 0                          0.368820                       0.344696
# 1                          0.336517                       0.277695
# 2                          0.336517                       0.277695
# 3                          0.296051                       0.264114
# 4                          0.296051                       0.264114
# ...                             ...                            ...
# 3770                       0.568909                       0.430252
# 3771                       0.568909                       0.430252
# 3772                       0.576675                       0.467178
# 3773                       0.436185                       0.429863
# 3775                       0.470551                       0.398979
#
#       Unnamed: 26  surface_sensible_heat_flux  skin_temperature  \
# 0             NaN                -1900802.000        285.825851
# 1             NaN                 -922280.000        285.876633
# 2             NaN                 -922280.000        285.876633
# 3             NaN                -1048284.000        285.620773
# 4             NaN                -1048284.000        285.620773
# ...           ...                         ...               ...
# 3770          NaN                -1500316.000        285.970383
# 3771          NaN                -1500316.000        285.970383
# 3772          NaN                -1463576.000        285.845383
# 3773          NaN                -1430555.667        285.619797
# 3775          NaN                -1480625.000        285.799484
#
#       u_component_of_wind_10m
# 0                    0.928651
# 1                    1.283631
# 2                    1.283631
# 3                    1.314393
# 4                    1.314393
# ...                       ...
# 3770                 1.067323
# 3771                 1.067323
# 3772                 0.908631
# 3773                 0.809266
# 3775                 1.022157
#
# [3300 rows x 30 columns]

# %%
df_clean.describe()
# Out:
#        system:index           B1          B10          B11           B2  \
# count  5.080000e+02  3300.000000  3300.000000  3300.000000  3300.000000
# mean   1.181497e+95     0.135807   277.227136   276.462418     0.114841
# std    2.662068e+96     0.026265    60.943800    61.400666     0.024993
# min    0.000000e+00     0.000000     0.000000     0.000000     0.000000
# 25%    3.176250e+03     0.130447   289.534990   289.067967     0.106068
# 50%    5.510500e+03     0.136871   290.384713   289.905454     0.114352
# 75%    7.622250e+03     0.145966   291.520642   291.003297     0.126490
# max    6.000000e+97     0.272144   298.175874   296.998416     0.273501
#
#                 B3           B4           B5           B6           B7  \
# count  3300.000000  3300.000000  3300.000000  3300.000000  3300.000000
# mean      0.095391     0.094387     0.197220     0.178798     0.124285
# std       0.025160     0.034431     0.071939     0.053914     0.048117
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.084129     0.073002     0.160340     0.151231     0.090628
# 50%       0.093100     0.088914     0.195687     0.178960     0.121437
# 75%       0.107279     0.113465     0.232779     0.209052     0.159087
# max       0.270435     0.291119     0.513513     0.349448     0.387621
#
#                 B8           B9  CLASS1  evaporation_from_bare_soil  \
# count  3300.000000  3300.000000     0.0                 3300.000000
# mean      0.093526     0.002364     NaN                   -0.001754
# std       0.027837     0.002430     NaN                    0.000192
# min       0.000000     0.000000     NaN                   -0.001935
# 25%       0.078357     0.001125     NaN                   -0.001887
# 50%       0.090021     0.001384     NaN                   -0.001796
# 75%       0.107697     0.002410     NaN                   -0.001711
# max       0.276777     0.026435     NaN                   -0.000991
#
#        evaporation_from_open_water_surfaces_excluding_oceans  \
# count                                        3300.000000
# mean                                           -0.000396
# std                                             0.000173
# min                                            -0.001174
# 25%                                            -0.000437
# 50%                                            -0.000353
# 75%                                            -0.000290
# max                                            -0.000231
#
#        evaporation_from_the_top_of_canopy  \
# count                         3300.000000
# mean                            -0.000282
# std                              0.000042
# min                             -0.000488
# 25%                             -0.000290
# 50%                             -0.000276
# 75%                             -0.000264
# max                             -0.000173
#
#        evaporation_from_vegetation_transpiration  potential_evaporation  \
# count                                3300.000000            3300.000000
# mean                                   -0.000032              -0.005064
# std                                     0.000072               0.001218
# min                                    -0.000554              -0.011821
# 25%                                    -0.000028              -0.004982
# 50%                                    -0.000001              -0.004743
# 75%                                     0.000000              -0.004525
# max                                     0.000000              -0.003164
#
#        snow_evaporation  total_evaporation  total_precipitation       runoff  \
# count            3300.0        3300.000000          3300.000000  3300.000000
# mean                0.0          -0.002464             0.001933     0.000876
# std                 0.0           0.000101             0.000347     0.000943
# min                 0.0          -0.002787             0.001495     0.000039
# 25%                 0.0          -0.002525             0.001649     0.000191
# 50%                 0.0          -0.002482             0.001825     0.000412
# 75%                 0.0          -0.002396             0.002165     0.001288
# max                 0.0          -0.002280             0.003448     0.003457
#
#        volumetric_soil_water_layer_1  volumetric_soil_water_layer_2  \
# count                    3300.000000                    3300.000000
# mean                        0.348567                       0.356852
# std                         0.093692                       0.093198
# min                         0.223206                       0.228714
# 25%                         0.302750                       0.310059
# 50%                         0.338958                       0.346130
# 75%                         0.345459                       0.353409
# max                         0.642365                       0.648285
#
#        volumetric_soil_water_layer_3  volumetric_soil_water_layer_4  \
# count                    3300.000000                    3300.000000
# mean                        0.374074                       0.347083
# std                         0.088326                       0.056658
# min                         0.241089                       0.262589
# 25%                         0.337906                       0.291931
# 50%                         0.362030                       0.352402
# 75%                         0.370148                       0.401917
# max                         0.650360                       0.482681
#
#        Unnamed: 26  surface_sensible_heat_flux  skin_temperature  \
# count          0.0                3.300000e+03       3300.000000
# mean           NaN               -1.344059e+06        281.847843
# std            NaN                2.964285e+05         33.145076
# min            NaN               -1.941689e+06          0.000000
# 25%            NaN               -1.525848e+06        285.622726
# 50%            NaN               -1.306320e+06        285.771164
# 75%            NaN               -1.177582e+06        285.876633
# max            NaN                0.000000e+00        286.087570
#
#        u_component_of_wind_10m
# count              3300.000000
# mean                  1.047787
# std                   0.274774
# min                   0.000000
# 25%                   0.826722
# 50%                   1.074647
# 75%                   1.282655
# max                   1.509706

# %% [markdown]
# # calculate parameters

# %%
# crop water supply
df_clean['CWS'] = df_clean['total_precipitation']
# Out:
# C:\Users\markc\AppData\Local\Temp/ipykernel_38684/1873534323.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['CWS'] = df_clean['total_precipitation']

# %%
# crop water requirement
# first part --- ET and runoff
df_clean['ET_runoff'] = df_clean['total_evaporation'] - df_clean['runoff'] 

# second part --- underground water
df_clean['underground_water'] = df_clean['volumetric_soil_water_layer_4'] - df_clean['volumetric_soil_water_layer_1']
df_clean
# Out:
# C:\Users\markc\AppData\Local\Temp/ipykernel_38684/3168625056.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['ET_runoff'] = df_clean['total_evaporation'] - df_clean['runoff']
# C:\Users\markc\AppData\Local\Temp/ipykernel_38684/3168625056.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['underground_water'] = df_clean['volumetric_soil_water_layer_4'] - df_clean['volumetric_soil_water_layer_1']
#       system:index        B1         B10         B11        B2        B3  \
# 0              NaN  0.156139  291.498028  290.941162  0.138696  0.119764
# 1              NaN  0.147215  291.636204  291.227004  0.127864  0.112384
# 2     5.000000e+17  0.146008  291.272759  290.903135  0.126530  0.112545
# 3              NaN  0.141016  293.390930  292.674697  0.119397  0.090476
# 4     5.899000e+03  0.147871  292.920083  292.304814  0.129631  0.110079
# ...            ...       ...         ...         ...       ...       ...
# 3770           NaN  0.145618  291.055979  290.808012  0.127851  0.110812
# 3771           NaN  0.158675  291.433356  291.092085  0.142223  0.129631
# 3772           NaN  0.144910  290.155193  289.948144  0.125949  0.111344
# 3773           NaN  0.141586  290.130126  289.827443  0.120740  0.100287
# 3775           NaN  0.151467  289.654867  289.260928  0.130318  0.108825
#
#             B4        B5        B6        B7        B8        B9  CLASS1  \
# 0     0.132346  0.197404  0.268908  0.212049  0.122958  0.001143     NaN
# 1     0.122462  0.167658  0.212057  0.174212  0.114253  0.001406     NaN
# 2     0.124327  0.169578  0.208004  0.170727  0.114837  0.001384     NaN
# 3     0.088609  0.119027  0.157172  0.123247  0.089042  0.001394     NaN
# 4     0.117619  0.164422  0.204815  0.167511  0.111686  0.001329     NaN
# ...        ...       ...       ...       ...       ...       ...     ...
# 3770  0.121387  0.205664  0.234846  0.160223  0.111828  0.001175     NaN
# 3771  0.139927  0.197233  0.216785  0.174099  0.132532  0.001187     NaN
# 3772  0.123562  0.189587  0.214093  0.161634  0.114771  0.001104     NaN
# 3773  0.100379  0.180001  0.174102  0.123306  0.099202  0.001365     NaN
# 3775  0.106633  0.185006  0.168603  0.124875  0.107008  0.004825     NaN
#
#       evaporation_from_bare_soil  \
# 0                      -0.001711
# 1                      -0.001935
# 2                      -0.001935
# 3                      -0.001796
# 4                      -0.001796
# ...                          ...
# 3770                   -0.001560
# 3771                   -0.001560
# 3772                   -0.001591
# 3773                   -0.001516
# 3775                   -0.001661
#
#       evaporation_from_open_water_surfaces_excluding_oceans  \
# 0                                             -0.000309
# 1                                             -0.000303
# 2                                             -0.000303
# 3                                             -0.000381
# 4                                             -0.000381
# ...                                                 ...
# 3770                                          -0.000569
# 3771                                          -0.000569
# 3772                                          -0.000447
# 3773                                          -0.000498
# 3775                                          -0.000541
#
#       evaporation_from_the_top_of_canopy  \
# 0                              -0.000264
# 1                              -0.000281
# 2                              -0.000281
# 3                              -0.000276
# 4                              -0.000276
# ...                                  ...
# 3770                           -0.000275
# 3771                           -0.000275
# 3772                           -0.000314
# 3773                           -0.000330
# 3775                           -0.000276
#
#       evaporation_from_vegetation_transpiration  potential_evaporation  \
# 0                                      0.000000              -0.005021
# 1                                      0.000000              -0.006930
# 2                                      0.000000              -0.006930
# 3                                     -0.000030              -0.006513
# 4                                     -0.000030              -0.006513
# ...                                         ...                    ...
# 3770                                   0.000000              -0.004666
# 3771                                   0.000000              -0.004666
# 3772                                  -0.000004              -0.004743
# 3773                                  -0.000010              -0.005141
# 3775                                   0.000000              -0.004640
#
#       snow_evaporation  total_evaporation  total_precipitation    runoff  \
# 0                  0.0          -0.002283             0.001690  0.000232
# 1                  0.0          -0.002518             0.001521  0.000191
# 2                  0.0          -0.002518             0.001521  0.000191
# 3                  0.0          -0.002482             0.001606  0.000412
# 4                  0.0          -0.002482             0.001606  0.000412
# ...                ...                ...                  ...       ...
# 3770               0.0          -0.002404             0.002084  0.000337
# 3771               0.0          -0.002404             0.002084  0.000337
# 3772               0.0          -0.002356             0.002334  0.000787
# 3773               0.0          -0.002354             0.002512  0.002150
# 3775               0.0          -0.002478             0.002058  0.000442
#
#       volumetric_soil_water_layer_1  volumetric_soil_water_layer_2  \
# 0                          0.340073                       0.346130
# 1                          0.302750                       0.310059
# 2                          0.302750                       0.310059
# 3                          0.258408                       0.267990
# 4                          0.258408                       0.267990
# ...                             ...                            ...
# 3770                       0.550140                       0.559784
# 3771                       0.550140                       0.559784
# 3772                       0.568878                       0.576279
# 3773                       0.432325                       0.440839
# 3775                       0.443161                       0.453354
#
#       volumetric_soil_water_layer_3  volumetric_soil_water_layer_4  \
# 0                          0.368820                       0.344696
# 1                          0.336517                       0.277695
# 2                          0.336517                       0.277695
# 3                          0.296051                       0.264114
# 4                          0.296051                       0.264114
# ...                             ...                            ...
# 3770                       0.568909                       0.430252
# 3771                       0.568909                       0.430252
# 3772                       0.576675                       0.467178
# 3773                       0.436185                       0.429863
# 3775                       0.470551                       0.398979
#
#       Unnamed: 26  surface_sensible_heat_flux  skin_temperature  \
# 0             NaN                -1900802.000        285.825851
# 1             NaN                 -922280.000        285.876633
# 2             NaN                 -922280.000        285.876633
# 3             NaN                -1048284.000        285.620773
# 4             NaN                -1048284.000        285.620773
# ...           ...                         ...               ...
# 3770          NaN                -1500316.000        285.970383
# 3771          NaN                -1500316.000        285.970383
# 3772          NaN                -1463576.000        285.845383
# 3773          NaN                -1430555.667        285.619797
# 3775          NaN                -1480625.000        285.799484
#
#       u_component_of_wind_10m       CWS  ET_runoff  underground_water
# 0                    0.928651  0.001690  -0.002515           0.004623
# 1                    1.283631  0.001521  -0.002709          -0.025055
# 2                    1.283631  0.001521  -0.002709          -0.025055
# 3                    1.314393  0.001606  -0.002894           0.005706
# 4                    1.314393  0.001606  -0.002894           0.005706
# ...                       ...       ...        ...                ...
# 3770                 1.067323  0.002084  -0.002741          -0.119888
# 3771                 1.067323  0.002084  -0.002741          -0.119888
# 3772                 0.908631  0.002334  -0.003143          -0.101700
# 3773                 0.809266  0.002512  -0.004504          -0.002462
# 3775                 1.022157  0.002058  -0.002920          -0.044182
#
# [3300 rows x 33 columns]

# %%
# calculate crop water requirement

df_clean['CWR'] = df_clean['ET_runoff'] + df_clean['underground_water'] 
df_clean['NDVI'] =  (df_clean['B5']-df_clean['B4'])/(df_clean['B5']+df_clean['B4'])
df_clean
# Out:
# C:\Users\markc\AppData\Local\Temp/ipykernel_38684/983297225.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['CWR'] = df_clean['ET_runoff'] + df_clean['underground_water']
# C:\Users\markc\AppData\Local\Temp/ipykernel_38684/983297225.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['NDVI'] =  (df_clean['B5']-df_clean['B4'])/(df_clean['B5']+df_clean['B4'])
#       system:index        B1         B10         B11        B2        B3  \
# 0              NaN  0.156139  291.498028  290.941162  0.138696  0.119764
# 1              NaN  0.147215  291.636204  291.227004  0.127864  0.112384
# 2     5.000000e+17  0.146008  291.272759  290.903135  0.126530  0.112545
# 3              NaN  0.141016  293.390930  292.674697  0.119397  0.090476
# 4     5.899000e+03  0.147871  292.920083  292.304814  0.129631  0.110079
# ...            ...       ...         ...         ...       ...       ...
# 3770           NaN  0.145618  291.055979  290.808012  0.127851  0.110812
# 3771           NaN  0.158675  291.433356  291.092085  0.142223  0.129631
# 3772           NaN  0.144910  290.155193  289.948144  0.125949  0.111344
# 3773           NaN  0.141586  290.130126  289.827443  0.120740  0.100287
# 3775           NaN  0.151467  289.654867  289.260928  0.130318  0.108825
#
#             B4        B5        B6        B7        B8        B9  CLASS1  \
# 0     0.132346  0.197404  0.268908  0.212049  0.122958  0.001143     NaN
# 1     0.122462  0.167658  0.212057  0.174212  0.114253  0.001406     NaN
# 2     0.124327  0.169578  0.208004  0.170727  0.114837  0.001384     NaN
# 3     0.088609  0.119027  0.157172  0.123247  0.089042  0.001394     NaN
# 4     0.117619  0.164422  0.204815  0.167511  0.111686  0.001329     NaN
# ...        ...       ...       ...       ...       ...       ...     ...
# 3770  0.121387  0.205664  0.234846  0.160223  0.111828  0.001175     NaN
# 3771  0.139927  0.197233  0.216785  0.174099  0.132532  0.001187     NaN
# 3772  0.123562  0.189587  0.214093  0.161634  0.114771  0.001104     NaN
# 3773  0.100379  0.180001  0.174102  0.123306  0.099202  0.001365     NaN
# 3775  0.106633  0.185006  0.168603  0.124875  0.107008  0.004825     NaN
#
#       evaporation_from_bare_soil  \
# 0                      -0.001711
# 1                      -0.001935
# 2                      -0.001935
# 3                      -0.001796
# 4                      -0.001796
# ...                          ...
# 3770                   -0.001560
# 3771                   -0.001560
# 3772                   -0.001591
# 3773                   -0.001516
# 3775                   -0.001661
#
#       evaporation_from_open_water_surfaces_excluding_oceans  \
# 0                                             -0.000309
# 1                                             -0.000303
# 2                                             -0.000303
# 3                                             -0.000381
# 4                                             -0.000381
# ...                                                 ...
# 3770                                          -0.000569
# 3771                                          -0.000569
# 3772                                          -0.000447
# 3773                                          -0.000498
# 3775                                          -0.000541
#
#       evaporation_from_the_top_of_canopy  \
# 0                              -0.000264
# 1                              -0.000281
# 2                              -0.000281
# 3                              -0.000276
# 4                              -0.000276
# ...                                  ...
# 3770                           -0.000275
# 3771                           -0.000275
# 3772                           -0.000314
# 3773                           -0.000330
# 3775                           -0.000276
#
#       evaporation_from_vegetation_transpiration  potential_evaporation  \
# 0                                      0.000000              -0.005021
# 1                                      0.000000              -0.006930
# 2                                      0.000000              -0.006930
# 3                                     -0.000030              -0.006513
# 4                                     -0.000030              -0.006513
# ...                                         ...                    ...
# 3770                                   0.000000              -0.004666
# 3771                                   0.000000              -0.004666
# 3772                                  -0.000004              -0.004743
# 3773                                  -0.000010              -0.005141
# 3775                                   0.000000              -0.004640
#
#       snow_evaporation  total_evaporation  total_precipitation    runoff  \
# 0                  0.0          -0.002283             0.001690  0.000232
# 1                  0.0          -0.002518             0.001521  0.000191
# 2                  0.0          -0.002518             0.001521  0.000191
# 3                  0.0          -0.002482             0.001606  0.000412
# 4                  0.0          -0.002482             0.001606  0.000412
# ...                ...                ...                  ...       ...
# 3770               0.0          -0.002404             0.002084  0.000337
# 3771               0.0          -0.002404             0.002084  0.000337
# 3772               0.0          -0.002356             0.002334  0.000787
# 3773               0.0          -0.002354             0.002512  0.002150
# 3775               0.0          -0.002478             0.002058  0.000442
#
#       volumetric_soil_water_layer_1  volumetric_soil_water_layer_2  \
# 0                          0.340073                       0.346130
# 1                          0.302750                       0.310059
# 2                          0.302750                       0.310059
# 3                          0.258408                       0.267990
# 4                          0.258408                       0.267990
# ...                             ...                            ...
# 3770                       0.550140                       0.559784
# 3771                       0.550140                       0.559784
# 3772                       0.568878                       0.576279
# 3773                       0.432325                       0.440839
# 3775                       0.443161                       0.453354
#
#       volumetric_soil_water_layer_3  volumetric_soil_water_layer_4  \
# 0                          0.368820                       0.344696
# 1                          0.336517                       0.277695
# 2                          0.336517                       0.277695
# 3                          0.296051                       0.264114
# 4                          0.296051                       0.264114
# ...                             ...                            ...
# 3770                       0.568909                       0.430252
# 3771                       0.568909                       0.430252
# 3772                       0.576675                       0.467178
# 3773                       0.436185                       0.429863
# 3775                       0.470551                       0.398979
#
#       Unnamed: 26  surface_sensible_heat_flux  skin_temperature  \
# 0             NaN                -1900802.000        285.825851
# 1             NaN                 -922280.000        285.876633
# 2             NaN                 -922280.000        285.876633
# 3             NaN                -1048284.000        285.620773
# 4             NaN                -1048284.000        285.620773
# ...           ...                         ...               ...
# 3770          NaN                -1500316.000        285.970383
# 3771          NaN                -1500316.000        285.970383
# 3772          NaN                -1463576.000        285.845383
# 3773          NaN                -1430555.667        285.619797
# 3775          NaN                -1480625.000        285.799484
#
#       u_component_of_wind_10m       CWS  ET_runoff  underground_water  \
# 0                    0.928651  0.001690  -0.002515           0.004623
# 1                    1.283631  0.001521  -0.002709          -0.025055
# 2                    1.283631  0.001521  -0.002709          -0.025055
# 3                    1.314393  0.001606  -0.002894           0.005706
# 4                    1.314393  0.001606  -0.002894           0.005706
# ...                       ...       ...        ...                ...
# 3770                 1.067323  0.002084  -0.002741          -0.119888
# 3771                 1.067323  0.002084  -0.002741          -0.119888
# 3772                 0.908631  0.002334  -0.003143          -0.101700
# 3773                 0.809266  0.002512  -0.004504          -0.002462
# 3775                 1.022157  0.002058  -0.002920          -0.044182
#
#            CWR      NDVI
# 0     0.002108  0.197296
# 1    -0.027764  0.155782
# 2    -0.027764  0.153965
# 3     0.002812  0.146493
# 4     0.002812  0.165946
# ...        ...       ...
# 3770 -0.122629  0.257687
# 3771 -0.122629  0.169968
# 3772 -0.104843  0.210841
# 3773 -0.006966  0.283981
# 3775 -0.047102  0.268732
#
# [3300 rows x 35 columns]

# %% [markdown]
# # select columns useful to our model

# %%
df_clean_v2 = df_clean[['CWS','ET_runoff','underground_water','CWR','surface_sensible_heat_flux','skin_temperature','u_component_of_wind_10m','NDVI']]
df_clean_v2.dropna()
# Out:
#            CWS  ET_runoff  underground_water       CWR  \
# 0     0.001690  -0.002515           0.004623  0.002108
# 1     0.001521  -0.002709          -0.025055 -0.027764
# 2     0.001521  -0.002709          -0.025055 -0.027764
# 3     0.001606  -0.002894           0.005706  0.002812
# 4     0.001606  -0.002894           0.005706  0.002812
# ...        ...        ...                ...       ...
# 3770  0.002084  -0.002741          -0.119888 -0.122629
# 3771  0.002084  -0.002741          -0.119888 -0.122629
# 3772  0.002334  -0.003143          -0.101700 -0.104843
# 3773  0.002512  -0.004504          -0.002462 -0.006966
# 3775  0.002058  -0.002920          -0.044182 -0.047102
#
#       surface_sensible_heat_flux  skin_temperature  u_component_of_wind_10m  \
# 0                   -1900802.000        285.825851                 0.928651
# 1                    -922280.000        285.876633                 1.283631
# 2                    -922280.000        285.876633                 1.283631
# 3                   -1048284.000        285.620773                 1.314393
# 4                   -1048284.000        285.620773                 1.314393
# ...                          ...               ...                      ...
# 3770                -1500316.000        285.970383                 1.067323
# 3771                -1500316.000        285.970383                 1.067323
# 3772                -1463576.000        285.845383                 0.908631
# 3773                -1430555.667        285.619797                 0.809266
# 3775                -1480625.000        285.799484                 1.022157
#
#           NDVI
# 0     0.197296
# 1     0.155782
# 2     0.153965
# 3     0.146493
# 4     0.165946
# ...        ...
# 3770  0.257687
# 3771  0.169968
# 3772  0.210841
# 3773  0.283981
# 3775  0.268732
#
# [3206 rows x 8 columns]

# %%
df_clean_v2.describe()
# Out:
#                CWS    ET_runoff  underground_water          CWR  \
# count  3300.000000  3300.000000        3300.000000  3300.000000
# mean      0.001933    -0.003340          -0.001484    -0.004824
# std       0.000347     0.000925           0.067006     0.066416
# min       0.001495    -0.005911          -0.205795    -0.208388
# 25%       0.001649    -0.003781          -0.033844    -0.036321
# 50%       0.001825    -0.002922           0.008866     0.005979
# 75%       0.002165    -0.002593           0.045639     0.041968
# max       0.003448    -0.002457           0.077347     0.071656
#
#        surface_sensible_heat_flux  skin_temperature  u_component_of_wind_10m  \
# count                3.300000e+03       3300.000000              3300.000000
# mean                -1.344059e+06        281.847843                 1.047787
# std                  2.964285e+05         33.145076                 0.274774
# min                 -1.941689e+06          0.000000                 0.000000
# 25%                 -1.525848e+06        285.622726                 0.826722
# 50%                 -1.306320e+06        285.771164                 1.074647
# 75%                 -1.177582e+06        285.876633                 1.282655
# max                  0.000000e+00        286.087570                 1.509706
#
#               NDVI
# count  3206.000000
# mean      0.336147
# std       0.171742
# min      -0.341186
# 25%       0.184894
# 50%       0.310057
# 75%       0.465850
# max       0.805801

# %% [markdown]
# # check the outliers of each column (no need to run)

# %%
boxplot = df_clean_v2.boxplot(column=['CWS','ET_runoff','underground_water','CWR'])

# %%
boxplot = df_clean_v2.boxplot(column=['surface_sensible_heat_flux'])

# %%
boxplot = df_clean_v2.boxplot(column=['NDVI'])

# %%
boxplot = df_clean_v2.boxplot(column=['u_component_of_wind_10m'])

# %% [markdown]
# # filter the data

# %%
# drop outliers in columns CWR < -0.1

df_clean_v3 = df_clean_v2[(df_clean_v2['CWR']>-0.1)& (df_clean_v2['surface_sensible_heat_flux']<-1)& (df_clean_v2['u_component_of_wind_10m']>0.4)&(df_clean_v2['NDVI']>-0.2)]
boxplot = df_clean_v3.boxplot(column=['CWS','ET_runoff','underground_water','CWR','NDVI'])

# %%
df_clean_v3.describe()
# Out:
#                CWS    ET_runoff  underground_water          CWR  \
# count  2830.000000  2830.000000        2830.000000  2830.000000
# mean      0.001904    -0.003395           0.016983     0.013587
# std       0.000359     0.000947           0.038764     0.037970
# min       0.001495    -0.005852          -0.079117    -0.081988
# 25%       0.001629    -0.003781          -0.017471    -0.019928
# 50%       0.001803    -0.002936           0.013244     0.010322
# 75%       0.002106    -0.002604           0.045639     0.041968
# max       0.003312    -0.002457           0.077347     0.071656
#
#        surface_sensible_heat_flux  skin_temperature  u_component_of_wind_10m  \
# count                2.830000e+03       2830.000000              2830.000000
# mean                -1.369748e+06        285.715911                 1.050056
# std                  2.609958e+05          0.195833                 0.254347
# min                 -1.941689e+06        284.573096                 0.406922
# 25%                 -1.528776e+06        285.620773                 0.811952
# 50%                 -1.367872e+06        285.732101                 1.074647
# 75%                 -1.182215e+06        285.819992                 1.282655
# max                 -9.222800e+05        286.087570                 1.496522
#
#               NDVI
# count  2830.000000
# mean      0.336086
# std       0.174472
# min      -0.197296
# 25%       0.179324
# 50%       0.300118
# 75%       0.473955
# max       0.805801

# %% [markdown]
# # try to find the relationship between cws and cwr

# %%
# scale the dataset into -1 to 1
from sklearn.preprocessing import StandardScaler

trans = StandardScaler()
df_scale = trans.fit_transform(df_clean_v3)
df_scale = pd.DataFrame(df_scale, columns=['CWS','ET_runoff','underground_water','CWR','surface_sensible_heat_flux','skin_temperature','u_component_of_wind_10m','NDVI'])
df_scale
# Out:
#            CWS  ET_runoff  underground_water       CWR  \
# 0    -0.596970   0.930130          -0.318898 -0.302380
# 1    -1.068416   0.725130          -1.084632 -1.089236
# 2    -1.068416   0.725130          -1.084632 -1.089236
# 3    -0.831298   0.529640          -0.290955 -0.283836
# 4    -0.831298   0.529640          -0.290955 -0.283836
# ...        ...        ...                ...       ...
# 2825  1.841159  -1.915565           1.216518  1.194205
# 2826  2.563671  -2.425951           1.557484  1.529578
# 2827  1.841159  -1.915565           1.216518  1.194205
# 2828  1.696099  -1.171648          -0.501701 -0.541397
# 2829  0.429611   0.502166          -1.578135 -1.598616
#
#       surface_sensible_heat_flux  skin_temperature  u_component_of_wind_10m  \
# 0                      -2.035084          0.561500                -0.477404
# 1                       1.714766          0.820855                 0.918499
# 2                       1.714766          0.820855                 0.918499
# 3                       1.231899         -0.485897                 1.039464
# 4                       1.231899         -0.485897                 1.039464
# ...                          ...               ...                      ...
# 2825                   -0.609422         -1.074435                -1.141755
# 2826                    0.298056         -1.413591                -1.712020
# 2827                   -0.609422         -1.074435                -1.141755
# 2828                   -0.233026         -0.490885                -0.946866
# 2829                   -0.424900          0.426835                -0.109708
#
#           NDVI
# 0    -0.795625
# 1    -1.033609
# 2    -1.044026
# 3    -1.086857
# 4    -0.975343
# ...        ...
# 2825 -1.301912
# 2826 -0.252030
# 2827 -0.392283
# 2828 -0.298700
# 2829 -0.386113
#
# [2830 rows x 8 columns]

# %%
import seaborn as sns

sns.pairplot(df_scale)

# %% [markdown]
# # split the data --- without ET_runoff & ground water

# %%
# create the x values for the model

x = df_scale[['CWR','surface_sensible_heat_flux','skin_temperature','u_component_of_wind_10m','NDVI'
             ]]
y= df_scale['CWS']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y,random_state=42,test_size = 0.3)
print('Training Data Count: {}'.format(x_train.shape[0]))
print('Testing Data Count: {}'.format(x_test.shape[0]))
# Out:
# Training Data Count: 1981
# Testing Data Count: 849

# %%
y_train
# Out:
# 2035   -0.831298
# 1788   -0.878722
# 1562    0.111594
# 2330   -1.140946
# 1474    0.853633
#           ...
# 1638   -0.878722
# 1095   -0.887091
# 1130   -0.711345
# 1294   -0.867563
# 860    -0.281743
# Name: CWS, Length: 1981, dtype: float64

# %% [markdown]
# # linear model

# %%
import time

# %%
from sklearn.linear_model import LinearRegression, Lasso
start_time = time.time()
model_lr = LinearRegression()
model_lr.fit(x_train, y_train)
line_time=(time.time()-start_time)
print("Running time", line_time)
print(model_lr.coef_)
# Out:
# Running time 0.003000497817993164
# [ 0.         -0.65007717 -0.0830773  -0.01769555 -0.21766494 -0.40670848
#   0.01644092]

# %%
import statsmodels.api as sm

x_train = sm.add_constant(x_train)
results = sm.OLS(y_train, x_train).fit()
results.summary()
# Out:
# C:\Users\markc\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CWS   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     2069.
# Date:                Fri, 24 Feb 2023   Prob (F-statistic):               0.00
# Time:                        15:56:24   Log-Likelihood:                -984.20
# No. Observations:                1981   AIC:                             1980.
# Df Residuals:                    1975   BIC:                             2014.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.0021      0.009     -0.237      0.812      -0.020       0.015
# CWR                            0.4983      0.011     43.628      0.000       0.476       0.521
# surface_sensible_heat_flux     0.1076      0.010     10.559      0.000       0.088       0.128
# skin_temperature              -0.2973      0.011    -28.057      0.000      -0.318      -0.277
# u_component_of_wind_10m       -0.4117      0.012    -34.359      0.000      -0.435      -0.388
# NDVI                           0.0114      0.009      1.269      0.205      -0.006       0.029
# ==============================================================================
# Omnibus:                      392.511   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              983.748
# Skew:                           1.069   Prob(JB):                    2.41e-214
# Kurtosis:                       5.710   Cond. No.                         2.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x_train=x_train.drop(['const'],axis=1)
x_train
# Out:
#            CWR  surface_sensible_heat_flux  skin_temperature  \
# 2035 -0.283836                    1.231899         -0.485897
# 1788 -1.669974                    1.542572          0.421847
# 1562  0.167647                   -0.510828         -0.555724
# 2330 -1.314635                    0.243065          1.509144
# 1474  0.747569                   -0.519289         -0.366195
# ...        ...                         ...               ...
# 1638 -1.669974                    1.542572          0.421847
# 1095 -1.532369                    0.736409          0.352020
# 1130 -0.200414                    0.623743          0.082690
# 1294 -0.882828                   -0.990277          0.521599
# 860  -0.117124                   -1.334129         -0.296368
#
#       u_component_of_wind_10m      NDVI
# 2035                 1.039464  1.163056
# 1788                 0.882017 -1.052880
# 1562                -0.715495  0.746321
# 2330                 0.670808 -0.952394
# 1474                -0.936305  0.412548
# ...                       ...       ...
# 1638                 0.882017  2.249837
# 1095                 0.377034  0.987866
# 1130                 0.914659  1.277167
# 1294                 0.096702  0.372974
# 860                 -0.104907 -0.749908
#
# [1981 rows x 5 columns]

# %%
lr_train_score=model_lr.score(x_train,y_train)
lr_test_score=model_lr.score(x_test,y_test)
print( "LR training score:", lr_train_score)
print("LR test score: ", lr_test_score)
# Out:
# LR training score: 0.8397135837363803
# LR test score:  0.82898404911835

# %% [markdown]
# # split the data --- with ET_runoff & ground water

# %%
x_v2 = df_scale[['ET_runoff','underground_water','surface_sensible_heat_flux','skin_temperature','u_component_of_wind_10m','NDVI']]
y= df_scale['CWS']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_v2, y,random_state=42,test_size = 0.3)
print('Training Data Count: {}'.format(x_train.shape[0]))
print('Testing Data Count: {}'.format(x_test.shape[0]))
# Out:
# Training Data Count: 1981
# Testing Data Count: 849

# %% [markdown]
# # linear model

# %%
from sklearn.linear_model import LinearRegression
start_time0 = time.time()
model_lr_v2 = LinearRegression()
model_lr_v2.fit(x_train, y_train)
lineartime=((time.time() - start_time0))
print("Running time:(seconds)",lineartime)
print(model_lr_v2.coef_)
# Out:
# Running time:(seconds) 0.002879619598388672
# [-0.65007717 -0.0830773  -0.01769555 -0.21766494 -0.40670848  0.01644092]

# %%
import statsmodels.api as sm

x_train = sm.add_constant(x_train)
results_v2 = sm.OLS(y_train, x_train).fit()
results_v2.summary()
# Out:
# C:\Users\markc\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CWS   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     5096.
# Date:                Fri, 24 Feb 2023   Prob (F-statistic):               0.00
# Time:                        17:40:01   Log-Likelihood:                -21.453
# No. Observations:                1981   AIC:                             56.91
# Df Residuals:                    1974   BIC:                             96.05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.0014      0.006     -0.246      0.806      -0.012       0.009
# ET_runoff                     -0.6501      0.012    -55.879      0.000      -0.673      -0.627
# underground_water             -0.0831      0.013     -6.579      0.000      -0.108      -0.058
# surface_sensible_heat_flux    -0.0177      0.007     -2.664      0.008      -0.031      -0.005
# skin_temperature              -0.2177      0.007    -32.640      0.000      -0.231      -0.205
# u_component_of_wind_10m       -0.4067      0.007    -55.158      0.000      -0.421      -0.392
# NDVI                           0.0164      0.006      2.976      0.003       0.006       0.027
# ==============================================================================
# Omnibus:                      857.704   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7937.691
# Skew:                           1.791   Prob(JB):                         0.00
# Kurtosis:                      12.128   Cond. No.                         4.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_pred = model_lr_v2.predict(x_test)

# %%
x_train=x_train.drop(['const'],axis=1)
x_train
# Out:
#       ET_runoff  underground_water  surface_sensible_heat_flux  \
# 2035   0.529640          -0.290955                    1.231899
# 1788   0.888919          -1.657475                    1.542572
# 1562   0.485259           0.152365                   -0.510828
# 2330   0.970284          -1.311400                    0.243065
# 1474  -0.291416           0.739373                   -0.519289
# ...         ...                ...                         ...
# 1638   0.888919          -1.657475                    1.542572
# 1095   0.878352          -1.522430                    0.736409
# 1130   0.537037          -0.209422                    0.623743
# 1294   0.991418          -0.888954                   -0.990277
# 860    0.686032          -0.131476                   -1.334129
#
#       skin_temperature  u_component_of_wind_10m      NDVI
# 2035         -0.485897                 1.039464  1.163056
# 1788          0.421847                 0.882017 -1.052880
# 1562         -0.555724                -0.715495  0.746321
# 2330          1.509144                 0.670808 -0.952394
# 1474         -0.366195                -0.936305  0.412548
# ...                ...                      ...       ...
# 1638          0.421847                 0.882017  2.249837
# 1095          0.352020                 0.377034  0.987866
# 1130          0.082690                 0.914659  1.277167
# 1294          0.521599                 0.096702  0.372974
# 860          -0.296368                -0.104907 -0.749908
#
# [1981 rows x 6 columns]

# %%
x_column = x_train.columns
x_column
# Out:
# Index(['ET_runoff', 'underground_water', 'surface_sensible_heat_flux',
#        'skin_temperature', 'u_component_of_wind_10m', 'NDVI'],
#       dtype='object')

# %%
lr_v2_train_score=model_lr_v2.score(x_train,y_train)
lr_v2_test_score=model_lr_v2.score(x_test,y_test)

print( "LR training score:", lr_v2_train_score)
print("LR test score: ", lr_v2_test_score)
# Out:
# LR training score: 0.9393582811639823
# LR test score:  0.9363956075386582

# %%
mse = mean_squared_error(y_test, y_pred)
print("mse: ", mse)
# Out:
# mse:  0.06553691290007291

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# # Tune the model

# %%
# tune alpha
# Increasing alpha may fix high variance (a sign of overfitting) by encouraging smaller weights, resulting in a decision boundary plot that appears with lesser curvatures.

# A problem with linear regression is that estimated coefficients of the model can become large, making the model sensitive to inputs and possibly unstable.
# This is particularly true for problems with few observations (samples) or less samples (n) than input predictors (p) or variables (so-called p >> n problems).

# A popular penalty is to penalize a model based on the sum of the absolute coefficient values. This is called the L1 penalty. An L1 penalty minimizes the size of 
# all coefficients and allows some coefficients to be minimized to the value zero, which removes the predictor from the model.

# An L1 penalty minimizes the size of all coefficients and allows any coefficient to go to the value of zero

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## step 1: Grid search

# %%
# Define the hyperparameters to optimize
# hyperparameters = { 'alpha': [ 0.01, 0.1],
#                    'solver': ['svd', 'lsqr', 'saga'],
#                    'learning_rate': ['constant', 'optimal', 'invscaling'],
#                    'max_iter': [100, 500, 1000]}

from sklearn.linear_model import LinearRegression, Lasso
# Define the hyperparameters to search over
param_grid_lr = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False]
}

param_grid_lasso = {
    'alpha': [0.01, 0.1, 1.0, 10.0, 100.0],
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False]
}

# %%
# Create a linear regression model
# lr_model = LinearRegression()

models = [LinearRegression(), Lasso()]
# Create the grid search object
# grid_search = GridSearchCV(estimator = lr_model, param_grid = hyperparameters, cv=5)

# Perform grid search over the hyperparameters using cross-validation

for model in models:
    
    # linear regression
    if model.__class__.__name__ == 'LinearRegression':
        grid_search = GridSearchCV(model, param_grid_lr, cv=5)

    # lasso    
    else:
        grid_search = GridSearchCV(model, param_grid_lasso, cv=5)
        
    grid_search.fit(x_train, y_train)
    
    # Print the best hyperparameters and corresponding score for each model
    print(model.__class__.__name__)
    print("Best hyperparameters:", grid_search.best_params_)
    print("Best score:", grid_search.best_score_)
# Out:
# LinearRegression
# Best hyperparameters: {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# Best score: 0.9387127044774666
# Lasso
# Best hyperparameters: {'alpha': 0.01, 'copy_X': True, 'fit_intercept': False, 'normalize': True}
# Best score: 0.9372718891738169

# %%
lr_model.get_params().keys()
# Out:
# dict_keys(['copy_X', 'fit_intercept', 'n_jobs', 'normalize', 'positive'])

# %%
# Lasso--original one
start_time1=time.time()
lasso_01 = linear_model.Lasso(alpha=0.1)
lasso_01.fit(x_train,y_train)
# pred_train_lasso = lasso.predict(x_train)

train_score=lasso_01.score(x_train,y_train)
test_score=lasso_01.score(x_test,y_test)
coeff_used = np.sum(lasso_01.coef_!=0)
coef_01 = lasso_01.coef_

ypred = lasso_01.predict(x_test)
mse = mean_squared_error(y_test, ypred)

# MSE_Lasso = np.sqrt(mean_squared_error(y_train,pred_train_lasso))
# R2_Lasso = r2_score(y_train, pred_train_lasso)
lasso01time=((time.time() - start_time1))
print("Running time:(seconds)",lasso01time)
print('MSE_Lasso',mse)
print ("training score:", train_score )
print ("test score: ", test_score)
print ("number of features used: ", coeff_used)
print ("coefficients:", coef_01)
# Out:
# Running time:(seconds) 0.011002302169799805
# MSE_Lasso 0.08535466856267909
# training score: 0.9204771519283865
# test score:  0.9171622281637506
# number of features used:  3
# coefficients: [-0.52107765  0.          0.         -0.15934945 -0.35786062  0.        ]

# %%
# Lasso with alpha=0.01
start_time2= time.time()
lasso001 = linear_model.Lasso(alpha=0.01, max_iter=10e5)
lasso001.fit(x_train,y_train)


train_score001=lasso001.score(x_train,y_train)
test_score001=lasso001.score(x_test,y_test)
coeff_used001 = np.sum(lasso001.coef_!=0)
coef_001 = lasso001.coef_
lasso001time=((time.time() - start_time2))
ypred = lasso001.predict(x_test)
mse = mean_squared_error(y_test, ypred)
print("Running time:(seconds)",lasso001time)
print('MSE_Lasso',mse)
print ("training score for alpha=0.01:", train_score001 )
print ("test score for alpha =0.01: ", test_score001)
print ("number of features used: for alpha =0.01:", coeff_used001)
print ("coefficients:", coef_001)
# Out:
# Running time:(seconds) 0.003000497817993164
# MSE_Lasso 0.06758770265906548
# training score for alpha=0.01: 0.9377683606458809
# test score for alpha =0.01:  0.9344052904652015
# number of features used: for alpha =0.01: 4
# coefficients: [-0.57917417 -0.          0.         -0.22034107 -0.3911223   0.00820612]

# %%
# Lasso with alpha=0.0001

start_time3=time.time()
lasso0001 = linear_model.Lasso(alpha=0.0001, max_iter=10e5)
lasso0001.fit(x_train,y_train)

train_score0001=lasso0001.score(x_train,y_train)
test_score0001=lasso0001.score(x_test,y_test)
coeff_used0001 = np.sum(lasso0001.coef_!=0)
coef_0001 = lasso0001.coef_
lasso0001time=(time.time() - start_time3)
ypred = lasso0001.predict(x_test)
mse = mean_squared_error(y_test, ypred)
print('MSE_Lasso',mse)
print("Running time:(seconds)",lasso0001time)
print ("training score for alpha=0.0001:", train_score0001)
print ("test score for alpha =0.0001: ", test_score0001)
print ("number of features used: for alpha =0.0001:", coeff_used0001)
print ("coefficients:", coef_0001)
# Out:
# MSE_Lasso 0.06553885736992601
# Running time:(seconds) 0.009734153747558594
# training score for alpha=0.0001: 0.9393580111229788
# test score for alpha =0.0001:  0.9363937204063814
# number of features used: for alpha =0.0001: 6
# coefficients: [-0.64916677 -0.08197816 -0.01732257 -0.21767367 -0.40655163  0.01636384]

# %%
# initialize data of lists.
data_score = {'training score':[train_score, train_score001,train_score0001],
        'test score':[test_score, test_score001,test_score0001]
        }
 
# Creates pandas DataFrame.
df_score = pd.DataFrame(data_score,index =['alpha=0.1',
                                'alpha=0.01',
                                'alpha=0.0001'])
 
# print the data
df_score
# Out:
#               training score  test score
# alpha=0.1           0.920477    0.917162
# alpha=0.01          0.937768    0.934405
# alpha=0.0001        0.939358    0.936394

# %%
plt.subplot(1,2,2)
plt.plot(lasso_01.coef_,alpha=0.7,linestyle='none',marker='*',markersize=5,color='red',label=r'Lasso; $\alpha = 1$',zorder=7) # alpha here is for transparency
plt.plot(lasso001.coef_,alpha=0.5,linestyle='none',marker='d',markersize=6,color='blue',label=r'Lasso; $\alpha = 0.01$') # alpha here is for transparency
plt.plot(lasso0001.coef_,alpha=0.8,linestyle='none',marker='v',markersize=6,color='black',label=r'Lasso; $\alpha = 0.0001$') # alpha here is for transparency
plt.plot(model_lr.coef_,alpha=0.7,linestyle='none',marker='o',markersize=5,color='green',label='Linear Regression',zorder=2)
plt.xlabel('Coefficient Index',fontsize=16)
plt.ylabel('Coefficient Magnitude',fontsize=16)
plt.legend(fontsize=10,loc=1)
plt.tight_layout()
plt.show()

# %%
# Create a function called lasso,
def lasso_func(alphas):
    '''
    Takes in a list of alphas. Outputs a dataframe containing the coefficients of lasso regressions from each alpha.
    '''
    # Create an empty data frame
    df = pd.DataFrame()
    
    # Create a column of feature names
    df['Feature Name'] = ['ET_runoff', 'underground_water', 'surface_sensible_heat_flux',
       'skin_temperature', 'u_component_of_wind_10m', 'NDVI']
    
    # For each alpha value in the list of alpha values,
    for alpha in alphas:
        # Create a lasso regression with that alpha value,
        lasso = linear_model.Lasso(alpha=alpha)
        
        # Fit the lasso regression
        lasso.fit(x_train,y_train)
        
        # Create a column name for that alpha value
        column_name = 'Alpha = %f' % alpha

        # Create a column of coefficient values
        df[column_name] = lasso.coef_
        
       
    # Return the datafram    
    return df

# %%
lasso_func([.0001, 0.01, 0.1])
# Out:
#                  Feature Name  Alpha = 0.000100  Alpha = 0.010000  \
# 0                   ET_runoff         -0.649167         -0.579174
# 1           underground_water         -0.081978         -0.000000
# 2  surface_sensible_heat_flux         -0.017323          0.000000
# 3            skin_temperature         -0.217674         -0.220341
# 4     u_component_of_wind_10m         -0.406552         -0.391122
# 5                        NDVI          0.016364          0.008206
#
#    Alpha = 0.100000
# 0         -0.521078
# 1          0.000000
# 2          0.000000
# 3         -0.159349
# 4         -0.357861
# 5          0.000000

# %%
# understanding of the result

# 'Reduce this under-fitting by reducing alpha and increasing number of iterations. Now α = 0.01, non-zero features =10, training and test score increases.
# Comparison of coefficient magnitude for two different values of alpha are shown in the left panel of figure 2. For alpha =1, we can see most of the coefficients are zero or nearly zero, which is not the case for alpha=0.01.
# Further reduce α =0.0001, non-zero features = 22. Training and test scores are similar to basic linear regression case.
# In the right panel of figure, for α = 0.0001, coefficients for Lasso regression and linear regression show close resemblance.'

# %% [markdown]
# # Polynomial Model

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import classification_report
start_time4 = time.time()
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(x_train)

model_poly = LinearRegression()

model_poly.fit(x_train, y_train)

y_predicted = model_poly.predict(x_train)
rmse = np.sqrt(mean_squared_error(y_train,y_predicted))
r2 = r2_score(y_train,y_predicted)
mse = mean_squared_error(y_train, y_predicted)
poly_time=(time.time() - start_time4)
print("Running time:(seconds)",poly_time)
print("mse", mse)
print ("rmse", rmse)
print ("r2", r2)
print("Training Score:",  model_poly.score(x_train, y_train))
print("Testing Score:",  model_poly.score(x_test, y_test))
# Out:
# Running time:(seconds) 0.009625673294067383
# mse 0.05983180114619193
# rmse 0.24460539884923213
# r2 0.9393582811639823
# Training Score: 0.9393582811639823
# Testing Score: 0.9363956075386582

# %% [markdown]
# # re-select columns. without any calculation sets

# %%
df_clean_new1 = df_clean[['CWS','total_evaporation','runoff','underground_water','surface_sensible_heat_flux','skin_temperature','u_component_of_wind_10m','NDVI']]
df_clean_new1.dropna()

# %%
boxplot = df_clean_new1.boxplot(column=['CWS','total_evaporation','runoff'])

# %%
boxplot = df_clean_new1.boxplot(column=['underground_water'])

# %%
df_clean_new2 = df_clean_new1[(df_clean_new1['CWS']<0.003)& (df_clean_new1['runoff']<0.003)& (df_clean_new1['underground_water']>-0.15)& (df_clean_new1['u_component_of_wind_10m']>0.4)&(df_clean_new1['NDVI']>-0.2)]
boxplot = df_clean_new2.boxplot(column=['CWS','runoff','underground_water','u_component_of_wind_10m','NDVI'])

# %%
# scale the dataset into -1 to 1
from sklearn.preprocessing import StandardScaler

trans = StandardScaler()
df_scale_new = trans.fit_transform(df_clean_new2)
df_scale_new = pd.DataFrame(df_scale, columns=['CWS','total_evaporation','runoff','underground_water','surface_sensible_heat_flux','skin_temperature','u_component_of_wind_10m','NDVI'])
df_scale_new

# %%
# split the data

# %%
x_v3 = df_scale_new[['total_evaporation','runoff','underground_water','surface_sensible_heat_flux','skin_temperature','u_component_of_wind_10m','NDVI'
             ]]
y= df_scale_new['CWS']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_v3, y,random_state=42,test_size = 0.3)
print('Training Data Count: {}'.format(x_train.shape[0]))
print('Testing Data Count: {}'.format(x_test.shape[0]))

# %% [markdown]
# # linear model

# %%
from sklearn.linear_model import LinearRegression
model_lr_new = LinearRegression()
model_lr_new.fit(x_train, y_train)
print(model_lr_new.coef_)

# %%
import statsmodels.api as sm

x_train = sm.add_constant(x_train)
results = sm.OLS(y_train, x_train).fit()
results.summary()

# %%
average_running_time = (lineartime +  poly_time + lasso0001time +lasso001time+ lasso01time+line_time)/6

# %%
print(average_running_time)
# Out:
# 0.007493336995442708
